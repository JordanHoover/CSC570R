# %%
#  Jordan Hoover
#  CSC570R Fall 2016
#  Assignment: 
#  Titaniac EDA

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df= pd.read_csv("train.csv") # load the csv file

# %%
df  #Show the Data Frame and get a quick idea of what the data looks like
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# find out how many attributes and instances are in the data
df.shape  #shows that there are 891 rows and 12 columns/attributes/features
# Out:
# (891, 12)

# %% [markdown]
# ### Do the Basic EDA for the assignment:
# For each variable:
# <li> Is it categorical? If it is, what are the categories?
# <li> If it is not categorical, what are the min, max, avg, and std deviation of the values?
# <li> Are there any missing values?
# <li> Show histogram(or other chart(s)) describing the distribution of the variable

# %% [markdown]
# # Variable: PassengerId
# <p> type: continuous
# <p> <em>Summary: </em>
#   This varaible represents the identification # for each passenger on the ship that we have in the data set.
# This appears to be the primary key for the data as each separate passenger ID represents an instance of a passenger on the Titanic.

# %%
# Statistics about the PassengerId variable (including min, max and std deviation)
df.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
# There are no missing values for PassengerId
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#  I was not going to include a historgram for PassengerId, because all values of PassengerId appear exactly once, 
#  which makes for a very uninteresting histogram showing the distribution,
#  But, I decided to still include a historgram for this variable to make sure I am fulfilling the instructions 
#  of the assignment:
df.PassengerId.hist()

# %%
df.PassengerId.value_counts().plot(kind='hist')

# %% [markdown]
# # Variable: Survived
# <p> type: categorical
# <p> <em>Summary: </em>
#   This varaible tells whether or not a passenger survived. Most passengers in this sample data did not survive (approx 38% survived, as seen in the mean for this variable.

# %%
# Statistics about the Survived variable (including min, max and std deviation)
df.Survived.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
# no missing values for 'Survived'
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# chart showing distribution of 'Survived'
df.Survived.value_counts().plot(kind='bar')

# %% [markdown]
# # Variable: Pclass
# <p> type: categorical
# <p> <em>Summary: </em>
#   This varaible tells the passenger's class, either 1, 2 or 3.  The majority of passengers in the sample are in class 3

# %%
df.Pclass.describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
#Pclass has no missing values
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# distribution of PClass
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# # Variable: Sex
# <p> type: categorical
# <p> <em>Summary: </em>
#   This varaible tells passenger sex. There were many more male passengers in the sample than females. There are no missing values.

# %%
df.Sex.describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# # Variable: Age
# <p> type: continuous
# <p> <em>Summary: </em>
#   This varaible tells passenger age. There are a number of missing values for 'Age' (177 missing out of 891 passengers).  The most common passenger age groups in the sample were 20's and 30's

# %%
df.Age.describe()
# Out:
# c:\program files\python35\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       80.000000
# Name: Age, dtype: float64

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.hist()

# %% [markdown]
# # Variable: SibSp
# <p> type: continuous
# <p> <em>Summary: </em>
#   This varaible represents the number of siblings/spouses aboard.  Most passengers in the sample had 1 or no spouses/siblings on the ship. There are no missing values.

# %%
df.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.hist()

# %% [markdown]
# # Variable: Parch
# <p> type: continuous
# <p> <em>Summary: </em>
#   This varaible represents # of parents and children.  It looks like most people in the sample didn't have much family on board.  There are no missing values.

# %%
df.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.hist()

# %% [markdown]
# # Variable: Ticket
# <p> type:continuous
# <p> <em>Summary: </em>
#   This varaible appears to be a ticket number for each passenger.   This variable seems continuous over categorical, because like PassengerId, every passenger has their own unique value for this attribute.  There are no missing values for 'Ticket'. I created some historgrams of the ticket variable to see what would happen, but it doesn't appear to have any useful information, as the values seem to be all over the place, with some tickets having only numbers and other tickets being a combination of letters, numbers, and other symbols.

# %%
df.Ticket.describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.value_counts().hist()

# %%
df.Ticket.value_counts().plot(kind='hist')

# %% [markdown]
# # Variable: Fare
# <p> type: continuous
# <p> <em>Summary: </em>
#   This varaible represents the fare paid by the passenger.  There are no missing values.

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.hist()

# %% [markdown]
# # Variable: Cabin
# <p> type: Categorical
# <p> <em>Summary: </em>
#   This varaible looks like it is different locations on the ship.  There are some missing values for Cabin.  It appears to be categorical because there can only be a certain number of cabins on the ship, and values are limited to the naming scheme that was chosen to name the cabins.

# %%
df.Cabin.describe()
# Out:
# count             204
# unique            147
# top       C23 C25 C27
# freq                4
# Name: Cabin, dtype: object

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df.Cabin.value_counts().hist()

# %% [markdown]
# # Variable: Embarked
# <p> type: Categorical
# <p> <em>Summary: </em>
#   This varaible represents which port the passenger embarked from.  There are a few missing values.

# %%
df.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# I am not quite sure the ways to create histograms of non-numerical data, but this data shows 
# the breakdown of how many passengers embarked from each port.
df.Embarked.value_counts().hist()

# %% [markdown]
# # A Few More EDA Questions I came up with after answering the basic EDA questions for each variable:
#  Most of the questions I came up with center around survival characteristcs as that seems the most interesting area to explore to me (ie, what things seemed to increse or decrease chances of survival)
# <li> Men vs Women
# <li> Children - I am guessing that the woman and children first off the boat was what made the survival difference between woman and men, but I am wondering if a female child is more likely to survive than a male child or if being of a young age is an equalizer
# <li> Among the children, did the youngest children make it or not?

# %%
# calculate the percentage of survivors:
342/891
# ***in Python 3, the type of the result of the int division is automatically made into float ***
# Out:
# 0.3838383838383838

# %%
## check to see if it is true that more women than men survived: 
fig, axs = plt.subplots(1,2)
df[df.Sex=='male'].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Males")
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh', ax=axs[1], title = "Females")

# %%
# clearly, most of the males survived and most of the females did not survive.

# %%
#  So for survival, clearly being a woman is greater than being a man, but what other things might be true about survival?
# what about age under 13?  Is there some chararastic that supercedes the importance of being a woman in survial or 
# some subset of the men who survive more than not survive even though they are male?
# I would guess that female>male   and bieng a child is probably more important than both: 

#chance of survival for just being under 13: 
df[(df.Age<13) ].Survived.value_counts().plot(kind='barh')
#df[df.Pclass==1].Survived.value_counts().plot(kind='barh')

# %%
# chance of survival for age under 13 and male: 
df[(df.Age<13) & (df.Sex=='male')].Survived.value_counts().plot(kind='barh')

# %% [markdown]
#  <li>It looks like if someone is under 13, they probably survive, even if they are male
#  <li> In fact, it looks like being male or female doesn't matter too much if someone is under 13
#  <li> Now I wonder if maybe some of the youngest children had trouble surviving b/c of the cold temperatures

# %%
df[(df.Age<3)].Survived.value_counts().plot(kind='barh')

# %%
# It looks like even the youngest children survived more often than not
